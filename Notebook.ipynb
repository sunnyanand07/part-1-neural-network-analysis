# %%
# !pip install tensorflow
# Out:
# Requirement already satisfied: tensorflow in c:\users\hp\appdata\local\programs\python\python312\lib\site-packages (2.21.0)
# Requirement already satisfied: absl-py>=1.0.0 in c:\users\hp\appdata\local\programs\python\python312\lib\site-packages (from tensorflow) (2.4.0)
# Requirement already satisfied: astunparse>=1.6.0 in c:\users\hp\appdata\local\programs\python\python312\lib\site-packages (from tensorflow) (1.6.3)
# Requirement already satisfied: flatbuffers>=25.9.23 in c:\users\hp\appdata\local\programs\python\python312\lib\site-packages (from tensorflow) (25.12.19)
# Requirement already satisfied: gast!=0.5.0,!=0.5.1,!=0.5.2,>=0.2.1 in c:\users\hp\appdata\local\programs\python\python312\lib\site-packages (from tensorflow) (0.7.0)
# Requirement already satisfied: google_pasta>=0.1.1 in c:\users\hp\appdata\local\programs\python\python312\lib\site-packages (from tensorflow) (0.2.0)
# Requirement already satisfied: libclang>=13.0.0 in c:\users\hp\appdata\local\programs\python\python312\lib\site-packages (from tensorflow) (18.1.1)
# Requirement already satisfied: opt_einsum>=2.3.2 in c:\users\hp\appdata\local\programs\python\python312\lib\site-packages (from tensorflow) (3.4.0)
# Requirement already satisfied: packaging in c:\users\hp\appdata\roaming\python\python312\site-packages (from tensorflow) (26.0)
# Requirement already satisfied: protobuf<8.0.0,>=6.31.1 in c:\users\hp\appdata\local\programs\python\python312\lib\site-packages (from tensorflow) (7.34.1)
# Requirement already satisfied: requests<3,>=2.21.0 in c:\users\hp\appdata\local\programs\python\python312\lib\site-packages (from tensorflow) (2.33.1)
# Requirement already satisfied: setuptools in c:\users\hp\appdata\local\programs\python\python312\lib\site-packages (from tensorflow) (82.0.1)
# Requirement already satisfied: six>=1.12.0 in c:\users\hp\appdata\roaming\python\python312\site-packages (from tensorflow) (1.17.0)
# Requirement already satisfied: termcolor>=1.1.0 in c:\users\hp\appdata\local\programs\python\python312\lib\site-packages (from tensorflow) (3.3.0)
# Requirement already satisfied: typing_extensions>=3.6.6 in c:\users\hp\appdata\local\programs\python\python312\lib\site-packages (from tensorflow) (4.15.0)
# Requirement already satisfied: wrapt>=1.11.0 in c:\users\hp\appdata\local\programs\python\python312\lib\site-packages (from tensorflow) (2.1.2)
# Requirement already satisfied: grpcio<2.0,>=1.24.3 in c:\users\hp\appdata\local\programs\python\python312\lib\site-packages (from tensorflow) (1.80.0)
# Requirement already satisfied: keras>=3.12.0 in c:\users\hp\appdata\local\programs\python\python312\lib\site-packages (from tensorflow) (3.14.1)
# Requirement already satisfied: numpy>=1.26.0 in c:\users\hp\appdata\local\programs\python\python312\lib\site-packages (from tensorflow) (2.4.4)
# Requirement already satisfied: h5py<3.15.0,>=3.11.0 in c:\users\hp\appdata\local\programs\python\python312\lib\site-packages (from tensorflow) (3.14.0)
# Requirement already satisfied: ml_dtypes<1.0.0,>=0.5.1 in c:\users\hp\appdata\local\programs\python\python312\lib\site-packages (from tensorflow) (0.5.4)
# Requirement already satisfied: wheel<1.0,>=0.23.0 in c:\users\hp\appdata\local\programs\python\python312\lib\site-packages (from astunparse>=1.6.0->tensorflow) (0.47.0)
# Requirement already satisfied: rich in c:\users\hp\appdata\local\programs\python\python312\lib\site-packages (from keras>=3.12.0->tensorflow) (15.0.0)
# Requirement already satisfied: namex in c:\users\hp\appdata\local\programs\python\python312\lib\site-packages (from keras>=3.12.0->tensorflow) (0.1.0)
# Requirement already satisfied: optree in c:\users\hp\appdata\local\programs\python\python312\lib\site-packages (from keras>=3.12.0->tensorflow) (0.19.1)
# Requirement already satisfied: charset_normalizer<4,>=2 in c:\users\hp\appdata\local\programs\python\python312\lib\site-packages (from requests<3,>=2.21.0->tensorflow) (3.4.7)
# Requirement already satisfied: idna<4,>=2.5 in c:\users\hp\appdata\local\programs\python\python312\lib\site-packages (from requests<3,>=2.21.0->tensorflow) (3.14)
# Requirement already satisfied: urllib3<3,>=1.26 in c:\users\hp\appdata\local\programs\python\python312\lib\site-packages (from requests<3,>=2.21.0->tensorflow) (2.7.0)
# Requirement already satisfied: certifi>=2023.5.7 in c:\users\hp\appdata\local\programs\python\python312\lib\site-packages (from requests<3,>=2.21.0->tensorflow) (2026.4.22)
# Requirement already satisfied: markdown-it-py>=2.2.0 in c:\users\hp\appdata\local\programs\python\python312\lib\site-packages (from rich->keras>=3.12.0->tensorflow) (4.2.0)
# Requirement already satisfied: pygments<3.0.0,>=2.13.0 in c:\users\hp\appdata\roaming\python\python312\site-packages (from rich->keras>=3.12.0->tensorflow) (2.19.2)
# Requirement already satisfied: mdurl~=0.1 in c:\users\hp\appdata\local\programs\python\python312\lib\site-packages (from markdown-it-py>=2.2.0->rich->keras>=3.12.0->tensorflow) (0.1.2)
# [notice] A new release of pip is available: 23.2.1 -> 26.1.1
# [notice] To update, run: python.exe -m pip install --upgrade pip

# %%
import pandas as pd 
import numpy as np 
import matplotlib.pyplot as plt 
import seaborn as sns

from sklearn.model_selection import train_test_split
from sklearn.preprocessing import LabelEncoder, StandardScaler
from sklearn.metrics import accuracy_score, confusion_matrix, classification_report

from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Dense
from tensorflow.keras.optimizers import Adam

#Load dataset 
file_path = ('customer_churn_nn.csv')
df = pd.read_csv(file_path)
print(df.head())
# Out:
#   customer_id   region plan_type   contract_type payment_method  \
# 0    CUST0001    South  Standard  Month-to-month     Debit Card
# 1    CUST0002     West   Premium  Month-to-month         Wallet
# 2    CUST0003  Central  Standard  Month-to-month    Credit Card
# 3    CUST0004     West   Premium  Month-to-month    Credit Card
# 4    CUST0005    North   Premium  Month-to-month    Net Banking
#
#    tenure_months  monthly_charges_inr  avg_login_days_per_month  \
# 0             30               687.40                        13
# 1             15              1029.74                        22
# 2             72               732.07                        13
# 3             22               959.51                        19
# 4             11               890.20                        18
#
#    support_tickets_last_90_days  payment_delay_days  data_usage_gb  \
# 0                             0                   0          87.97
# 1                             3                   1          82.17
# 2                             0                  11          89.39
# 3                             2                   3         139.73
# 4                             2                   6         156.43
#
#    satisfaction_score  last_complaint_days_ago  discount_percent  \
# 0                 8.0                       67                 0
# 1                 5.7                       69                 0
# 2                 6.4                       63                10
# 3                 7.2                      130                 5
# 4                 5.8                        0                 5
#
#    autopay_enabled  referral_count  churn
# 0                0               0      0
# 1                0               0      0
# 2                0               0      0
# 3                0               0      0
# 4                1               2      0

# %%
print('Shape of dataset:', df.shape)
# Out:
# Shape of dataset: (2000, 17)

# %%
print(df.dtypes)
# Out:
# customer_id                         str
# region                              str
# plan_type                           str
# contract_type                       str
# payment_method                      str
# tenure_months                     int64
# monthly_charges_inr             float64
# avg_login_days_per_month          int64
# support_tickets_last_90_days      int64
# payment_delay_days                int64
# data_usage_gb                   float64
# satisfaction_score              float64
# last_complaint_days_ago           int64
# discount_percent                  int64
# autopay_enabled                   int64
# referral_count                    int64
# churn                             int64
# dtype: object

# %%
print(df.isnull().sum())
# Out:
# customer_id                     0
# region                          0
# plan_type                       0
# contract_type                   0
# payment_method                  0
# tenure_months                   0
# monthly_charges_inr             0
# avg_login_days_per_month        0
# support_tickets_last_90_days    0
# payment_delay_days              0
# data_usage_gb                   0
# satisfaction_score              0
# last_complaint_days_ago         0
# discount_percent                0
# autopay_enabled                 0
# referral_count                  0
# churn                           0
# dtype: int64

# %%
print(df.describe())
# Out:
#        tenure_months  monthly_charges_inr  avg_login_days_per_month  \
# count    2000.000000          2000.000000               2000.000000
# mean       25.362000           766.487295                 18.099000
# std        14.128651           393.420070                  5.400628
# min         1.000000           255.450000                  0.000000
# 25%        15.000000           427.782500                 15.000000
# 50%        23.000000           688.355000                 18.000000
# 75%        33.000000          1007.372500                 22.000000
# max        72.000000          2156.520000                 30.000000
#
#        support_tickets_last_90_days  payment_delay_days  data_usage_gb  \
# count                   2000.000000         2000.000000    2000.000000
# mean                       1.953000            3.555000      90.007625
# std                        1.463852            3.885682      53.215719
# min                        0.000000            0.000000       0.500000
# 25%                        1.000000            1.000000      51.777500
# 50%                        2.000000            2.000000      80.245000
# 75%                        3.000000            5.000000     119.097500
# max                        8.000000           31.000000     265.510000
#
#        satisfaction_score  last_complaint_days_ago  discount_percent  \
# count          2000.00000              2000.000000       2000.000000
# mean              6.87395                46.616500          8.255000
# std               1.52428                55.065775          7.553708
# min               1.00000                 0.000000          0.000000
# 25%               5.87500                 6.000000          0.000000
# 50%               6.80000                28.500000          5.000000
# 75%               8.00000                68.000000         15.000000
# max              10.00000               424.000000         20.000000
#
#        autopay_enabled  referral_count        churn
# count      2000.000000     2000.000000  2000.000000
# mean          0.597500        0.918000     0.015500
# std           0.490524        1.041546     0.123561
# min           0.000000        0.000000     0.000000
# 25%           0.000000        0.000000     0.000000
# 50%           1.000000        1.000000     0.000000
# 75%           1.000000        1.000000     0.000000
# max           1.000000        7.000000     1.000000

# %%
sns.countplot(x='churn', data=df)
plt.title('Distribution of Churn')
plt.show()

# %%
# Data Preprocessing

# customer_id is not useful for prediction
df = df.drop('customer_id', axis=1)

label_encoder = LabelEncoder()

categorical_cols =['region', 'plan_type', 'contract_type', 'payment_method']

for col in categorical_cols:
    df[col] = label_encoder.fit_transform(df[col])

# %% [markdown]
# Neural networks work only with numbers.So categorical text values are converted into numeric values.

# %%
X = df.drop('churn', axis=1)
y = df['churn']

# %%
scaler = StandardScaler()
X_scaled = scaler.fit_transform(X)

# %% [markdown]
# Feature scaling improves neural network performance. It makes all values lie on a similar scale

# %%
X_train, X_test, y_train, y_test = train_test_split(
    X_scaled,
    y,
    test_size=0.2,
    random_state=42
)

# %%
# Neural Network Model Building

model = Sequential()

#input + hidden layer
model.add(Dense(16, activation='relu', input_dim=X_train.shape[1]))

#second Hidden layer
model.add(Dense(8, activation='relu'))

#Output layer
model.add(Dense(1, activation='sigmoid'))
# Out:
# c:\Users\Hp\AppData\Local\Programs\Python\Python312\Lib\site-packages\keras\src\layers\core\dense.py:107: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#   super().__init__(activity_regularizer=activity_regularizer, **kwargs)

# %%
model.compile(
    optimizer='adam',
    loss='binary_crossentropy',
    metrics=['accuracy'])
# Out:
# WARNING:tensorflow:TensorFlow GPU support is not available on native Windows for TensorFlow >= 2.11. Even if CUDA/cuDNN are installed, GPU will not be used. Please use WSL2 or the TensorFlow-DirectML plugin.

# %%
model.summary()
# Out:
# Model: "sequential"
# ┏━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━┓
# ┃ Layer (type)                    ┃ Output Shape           ┃       Param # ┃
# ┡━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━┩
# │ dense (Dense)                   │ (None, 16)             │           256 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense_1 (Dense)                 │ (None, 8)              │           136 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense_2 (Dense)                 │ (None, 1)              │             9 │
# └─────────────────────────────────┴────────────────────────┴───────────────┘
#  Total params: 401 (1.57 KB)
#  Trainable params: 401 (1.57 KB)
#  Non-trainable params: 0 (0.00 B)

# %%
# Training and Evaluation

history = model.fit(
    X_train,
    y_train,
    epochs=20,
    batch_size=32,
    validation_split=0.2
)
# Out:
# Epoch 1/20
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 13s 55ms/step - accuracy: 0.4586 - loss: 0.7450 - val_accuracy: 0.6969 - val_loss: 0.5893
# Epoch 2/20
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 1s 24ms/step - accuracy: 0.8047 - loss: 0.4882 - val_accuracy: 0.9031 - val_loss: 0.4063
# Epoch 3/20
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 1s 27ms/step - accuracy: 0.9383 - loss: 0.3395 - val_accuracy: 0.9719 - val_loss: 0.3015
# Epoch 4/20
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 1s 30ms/step - accuracy: 0.9797 - loss: 0.2435 - val_accuracy: 0.9781 - val_loss: 0.2381
# Epoch 5/20
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 1s 26ms/step - accuracy: 0.9867 - loss: 0.1806 - val_accuracy: 0.9781 - val_loss: 0.1999
# Epoch 6/20
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 3s 77ms/step - accuracy: 0.9867 - loss: 0.1417 - val_accuracy: 0.9781 - val_loss: 0.1769
# Epoch 7/20
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 1s 31ms/step - accuracy: 0.9867 - loss: 0.1178 - val_accuracy: 0.9781 - val_loss: 0.1628
# Epoch 8/20
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 1s 28ms/step - accuracy: 0.9867 - loss: 0.1024 - val_accuracy: 0.9781 - val_loss: 0.1493
# Epoch 9/20
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 1s 29ms/step - accuracy: 0.9867 - loss: 0.0917 - val_accuracy: 0.9781 - val_loss: 0.1409
# Epoch 10/20
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 1s 24ms/step - accuracy: 0.9867 - loss: 0.0842 - val_accuracy: 0.9781 - val_loss: 0.1346
# Epoch 11/20
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 1s 26ms/step - accuracy: 0.9867 - loss: 0.0782 - val_accuracy: 0.9781 - val_loss: 0.1272
# Epoch 12/20
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 1s 31ms/step - accuracy: 0.9867 - loss: 0.0732 - val_accuracy: 0.9781 - val_loss: 0.1211
# Epoch 13/20
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 2s 25ms/step - accuracy: 0.9867 - loss: 0.0688 - val_accuracy: 0.9781 - val_loss: 0.1164
# Epoch 14/20
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 1s 26ms/step - accuracy: 0.9867 - loss: 0.0654 - val_accuracy: 0.9781 - val_loss: 0.1135
# Epoch 15/20
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 1s 27ms/step - accuracy: 0.9867 - loss: 0.0624 - val_accuracy: 0.9781 - val_loss: 0.1114
# Epoch 16/20
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 2s 39ms/step - accuracy: 0.9867 - loss: 0.0600 - val_accuracy: 0.9781 - val_loss: 0.1096
# Epoch 17/20
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 1s 31ms/step - accuracy: 0.9867 - loss: 0.0579 - val_accuracy: 0.9781 - val_loss: 0.1075
# Epoch 18/20
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 1s 23ms/step - accuracy: 0.9867 - loss: 0.0563 - val_accuracy: 0.9781 - val_loss: 0.1062
# Epoch 19/20
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 1s 26ms/step - accuracy: 0.9867 - loss: 0.0544 - val_accuracy: 0.9781 - val_loss: 0.1066
# Epoch 20/20
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 1s 28ms/step - accuracy: 0.9867 - loss: 0.0529 - val_accuracy: 0.9781 - val_loss: 0.1068

# %%
plt.plot(history.history['accuracy'], label='Training Accuracy')
plt.plot(history.history['val_accuracy'], label='Validation Accuracy')
plt.legend()
plt.title('Model Accuracy')
plt.show()

# %%
plt.plot(history.history['loss'], label='Training Loss')
plt.plot(history.history['val_loss'], label='Validation Loss')
plt.legend()
plt.title('Model Loss')
plt.show()

# %%
loss, accuracy = model.evaluate(X_test, y_test)

print('Test Loss:', loss)
print('Test Accuracy:', accuracy)
# Out:
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 2s 35ms/step - accuracy: 0.9825 - loss: 0.0763
# Test Loss: 0.07633211463689804
# Test Accuracy: 0.9825000166893005

# %%
predictions = model.predict(X_test)
predictions = (predictions > 0.5).astype(int)
# Out:
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 1s 61ms/step

# %%
cm = confusion_matrix(y_test, predictions)

sns.heatmap(cm, annot=True, fmt='d', cmap='Blues')
plt.title('Confusion Matrix')
plt.xlabel('Predictd')
plt.ylabel('Actual')
plt.show()

# %%
print(classification_report(y_test, predictions))
# Out:
#               precision    recall  f1-score   support
#
#            0       0.98      1.00      0.99       393
#            1       0.00      0.00      0.00         7
#
#     accuracy                           0.98       400
#    macro avg       0.49      0.50      0.50       400
# weighted avg       0.97      0.98      0.97       400
# c:\Users\Hp\AppData\Local\Programs\Python\Python312\Lib\site-packages\sklearn\metrics\_classification.py:1833: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, f"{metric.capitalize()} is", result.shape[0])
# c:\Users\Hp\AppData\Local\Programs\Python\Python312\Lib\site-packages\sklearn\metrics\_classification.py:1833: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, f"{metric.capitalize()} is", result.shape[0])
# c:\Users\Hp\AppData\Local\Programs\Python\Python312\Lib\site-packages\sklearn\metrics\_classification.py:1833: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, f"{metric.capitalize()} is", result.shape[0])

# %% [markdown]
# ### Brief Explaination of the result
#
# The neural network model performed well on the dataset with good training and testing accuracy.
# The loss decreased gradually during training, indicating effective learning.
# The confusion matrix showed that most predictions were correctly classified.
# A small difference between training and testing accuracy suggests minimal overfitting

# %%
# Hyperparameter Experimentation 

model = Sequential()
model.add(Dense(32, activation='relu', input_dim=X_train.shape[1]))
model.add(Dense(16, activation='relu'))
model.add(Dense(1, activation='sigmoid'))
# Out:
# c:\Users\Hp\AppData\Local\Programs\Python\Python312\Lib\site-packages\keras\src\layers\core\dense.py:107: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#   super().__init__(activity_regularizer=activity_regularizer, **kwargs)

# %%
optimizer = Adam(learning_rate=0.001)

model.compile(
    optimizer=optimizer,
    loss='binary_crossentropy',
    metrics=['accuracy']
)

# %%
history = model.fit(
    X_train,
    y_train,
    epochs=50,
    batch_size=32,
    validation_split=0.2
)
# Out:
# Epoch 1/50
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 10s 54ms/step - accuracy: 0.7078 - loss: 0.5809 - val_accuracy: 0.9563 - val_loss: 0.3908
# Epoch 2/50
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 1s 25ms/step - accuracy: 0.9836 - loss: 0.2735 - val_accuracy: 0.9781 - val_loss: 0.1999
# Epoch 3/50
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 1s 32ms/step - accuracy: 0.9867 - loss: 0.1360 - val_accuracy: 0.9781 - val_loss: 0.1290
# Epoch 4/50
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 3s 31ms/step - accuracy: 0.9867 - loss: 0.0906 - val_accuracy: 0.9781 - val_loss: 0.1102
# Epoch 5/50
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 1s 26ms/step - accuracy: 0.9867 - loss: 0.0768 - val_accuracy: 0.9781 - val_loss: 0.1026
# Epoch 6/50
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 1s 29ms/step - accuracy: 0.9867 - loss: 0.0702 - val_accuracy: 0.9781 - val_loss: 0.0990
# Epoch 7/50
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 1s 27ms/step - accuracy: 0.9867 - loss: 0.0664 - val_accuracy: 0.9781 - val_loss: 0.0956
# Epoch 8/50
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 1s 27ms/step - accuracy: 0.9867 - loss: 0.0631 - val_accuracy: 0.9781 - val_loss: 0.0942
# Epoch 9/50
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 1s 33ms/step - accuracy: 0.9867 - loss: 0.0605 - val_accuracy: 0.9781 - val_loss: 0.0926
# Epoch 10/50
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 1s 32ms/step - accuracy: 0.9867 - loss: 0.0584 - val_accuracy: 0.9781 - val_loss: 0.0914
# Epoch 11/50
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 1s 27ms/step - accuracy: 0.9867 - loss: 0.0559 - val_accuracy: 0.9781 - val_loss: 0.0898
# Epoch 12/50
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 1s 30ms/step - accuracy: 0.9867 - loss: 0.0538 - val_accuracy: 0.9781 - val_loss: 0.0894
# Epoch 13/50
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 1s 29ms/step - accuracy: 0.9867 - loss: 0.0520 - val_accuracy: 0.9781 - val_loss: 0.0886
# Epoch 14/50
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 1s 30ms/step - accuracy: 0.9867 - loss: 0.0502 - val_accuracy: 0.9781 - val_loss: 0.0891
# Epoch 15/50
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 1s 30ms/step - accuracy: 0.9867 - loss: 0.0487 - val_accuracy: 0.9781 - val_loss: 0.0892
# Epoch 16/50
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 1s 28ms/step - accuracy: 0.9867 - loss: 0.0473 - val_accuracy: 0.9781 - val_loss: 0.0876
# Epoch 17/50
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 1s 26ms/step - accuracy: 0.9867 - loss: 0.0456 - val_accuracy: 0.9781 - val_loss: 0.0886
# Epoch 18/50
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 1s 30ms/step - accuracy: 0.9867 - loss: 0.0444 - val_accuracy: 0.9781 - val_loss: 0.0888
# Epoch 19/50
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 1s 24ms/step - accuracy: 0.9867 - loss: 0.0434 - val_accuracy: 0.9781 - val_loss: 0.0886
# Epoch 20/50
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 1s 26ms/step - accuracy: 0.9867 - loss: 0.0417 - val_accuracy: 0.9781 - val_loss: 0.0889
# Epoch 21/50
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 1s 27ms/step - accuracy: 0.9867 - loss: 0.0404 - val_accuracy: 0.9781 - val_loss: 0.0890
# Epoch 22/50
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 1s 30ms/step - accuracy: 0.9867 - loss: 0.0393 - val_accuracy: 0.9781 - val_loss: 0.0891
# Epoch 23/50
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 1s 27ms/step - accuracy: 0.9867 - loss: 0.0383 - val_accuracy: 0.9781 - val_loss: 0.0897
# Epoch 24/50
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 1s 22ms/step - accuracy: 0.9867 - loss: 0.0372 - val_accuracy: 0.9781 - val_loss: 0.0908
# Epoch 25/50
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 1s 24ms/step - accuracy: 0.9867 - loss: 0.0360 - val_accuracy: 0.9781 - val_loss: 0.0907
# Epoch 26/50
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 1s 25ms/step - accuracy: 0.9867 - loss: 0.0349 - val_accuracy: 0.9781 - val_loss: 0.0914
# Epoch 27/50
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 1s 26ms/step - accuracy: 0.9867 - loss: 0.0339 - val_accuracy: 0.9781 - val_loss: 0.0920
# Epoch 28/50
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 1s 27ms/step - accuracy: 0.9867 - loss: 0.0333 - val_accuracy: 0.9781 - val_loss: 0.0934
# Epoch 29/50
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 1s 27ms/step - accuracy: 0.9883 - loss: 0.0318 - val_accuracy: 0.9781 - val_loss: 0.0939
# Epoch 30/50
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 1s 26ms/step - accuracy: 0.9875 - loss: 0.0309 - val_accuracy: 0.9781 - val_loss: 0.0954
# Epoch 31/50
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 1s 27ms/step - accuracy: 0.9883 - loss: 0.0294 - val_accuracy: 0.9781 - val_loss: 0.0963
# Epoch 32/50
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 1s 31ms/step - accuracy: 0.9891 - loss: 0.0287 - val_accuracy: 0.9781 - val_loss: 0.0980
# Epoch 33/50
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 1s 28ms/step - accuracy: 0.9891 - loss: 0.0271 - val_accuracy: 0.9781 - val_loss: 0.0993
# Epoch 34/50
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 1s 29ms/step - accuracy: 0.9914 - loss: 0.0258 - val_accuracy: 0.9781 - val_loss: 0.1027
# Epoch 35/50
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 1s 33ms/step - accuracy: 0.9914 - loss: 0.0245 - val_accuracy: 0.9781 - val_loss: 0.1016
# Epoch 36/50
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 2s 35ms/step - accuracy: 0.9922 - loss: 0.0234 - val_accuracy: 0.9781 - val_loss: 0.1065
# Epoch 37/50
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 1s 31ms/step - accuracy: 0.9914 - loss: 0.0223 - val_accuracy: 0.9781 - val_loss: 0.1052
# Epoch 38/50
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 1s 30ms/step - accuracy: 0.9922 - loss: 0.0209 - val_accuracy: 0.9781 - val_loss: 0.1080
# Epoch 39/50
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 2s 35ms/step - accuracy: 0.9930 - loss: 0.0198 - val_accuracy: 0.9781 - val_loss: 0.1088
# Epoch 40/50
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 2s 36ms/step - accuracy: 0.9930 - loss: 0.0184 - val_accuracy: 0.9781 - val_loss: 0.1127
# Epoch 41/50
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 2s 31ms/step - accuracy: 0.9922 - loss: 0.0173 - val_accuracy: 0.9781 - val_loss: 0.1127
# Epoch 42/50
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 2s 42ms/step - accuracy: 0.9930 - loss: 0.0164 - val_accuracy: 0.9781 - val_loss: 0.1173
# Epoch 43/50
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 2s 43ms/step - accuracy: 0.9937 - loss: 0.0154 - val_accuracy: 0.9781 - val_loss: 0.1212
# Epoch 44/50
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 2s 34ms/step - accuracy: 0.9930 - loss: 0.0145 - val_accuracy: 0.9781 - val_loss: 0.1220
# Epoch 45/50
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 3s 31ms/step - accuracy: 0.9945 - loss: 0.0135 - val_accuracy: 0.9781 - val_loss: 0.1235
# Epoch 46/50
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 2s 25ms/step - accuracy: 0.9945 - loss: 0.0125 - val_accuracy: 0.9781 - val_loss: 0.1294
# Epoch 47/50
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 1s 26ms/step - accuracy: 0.9945 - loss: 0.0119 - val_accuracy: 0.9781 - val_loss: 0.1287
# Epoch 48/50
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 1s 26ms/step - accuracy: 0.9945 - loss: 0.0111 - val_accuracy: 0.9781 - val_loss: 0.1307
# Epoch 49/50
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 1s 25ms/step - accuracy: 0.9945 - loss: 0.0105 - val_accuracy: 0.9781 - val_loss: 0.1336
# Epoch 50/50
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 1s 27ms/step - accuracy: 0.9969 - loss: 0.0101 - val_accuracy: 0.9781 - val_loss: 0.1388

# %% [markdown]
# # Final Reflection
#
# 1. Role of Weights and Biases
# Weights help the model learn the importance of features.Bias helps shift activation values for better learning.
#
# 2. Why Activation Function is Required
# Activation functions introduce non-linearity. Without them, neural networks behave like linear models.
#
# 3. Effect of Learning Rate
# -> Very high learning rate causes unstable learning.
# -> Very low learning rate makes training very slow.
#
# 4. Underfitting vs Overfitting
# -> Underfitting happens when the model learns too little.'
# -> Overfitting happens when the model memorizes training data.
